# %%
import pandas as pd

# %%
jhcounty_cases = pd.read_csv('Cases by day by county.csv')
jhcounty_cases
# Out:
#            UID iso2 iso3  code3  FIPS          Admin2  \
# 0           16   AS  ASM     16  60.0             NaN
# 1          316   GU  GUM    316  66.0             NaN
# 2          580   MP  MNP    580  69.0             NaN
# 3          630   PR  PRI    630  72.0             NaN
# 4          850   VI  VIR    850  78.0             NaN
# ...        ...  ...  ...    ...   ...             ...
# 3256  84070016   US  USA    840   NaN    Central Utah
# 3257  84070017   US  USA    840   NaN  Southeast Utah
# 3258  84070018   US  USA    840   NaN  Southwest Utah
# 3259  84070019   US  USA    840   NaN       TriCounty
# 3260  84070020   US  USA    840   NaN    Weber-Morgan
#
#                 Province_State Country_Region        Lat       Long_  ...  \
# 0               American Samoa             US -14.271000 -170.132000  ...
# 1                         Guam             US  13.444300  144.793700  ...
# 2     Northern Mariana Islands             US  15.097900  145.673900  ...
# ...

# %%
jhcounty_grouped_state = jhcounty_cases.groupby('Province_State')
jhcounty_grouped_state['3/27/2020'].sum()
# Out:
# Province_State
# Alabama                       587
# Alaska                         58
# American Samoa                  0
# Arizona                       665
# Arkansas                      381
# California                   4657
# Colorado                     1738
# Connecticut                  1291
# Delaware                      163
# Diamond Princess               49
# District of Columbia          271
# Florida                      2900
# Georgia                      2000
# Grand Princess                 28
# Guam                           51
# Hawaii                        106
# Idaho                         205
# Illinois                     3024
# Indiana                       979
# Iowa                          235
# Kansas                        206
# Kentucky                      301
# Louisiana                    2744
# Maine                         168
# Maryland                      775
# Massachusetts                3240
# Michigan                     3848
# ...

# %%
jhcounty_grouped_state['5/14/2020'].sum()
# Out:
# Province_State
# Alabama                      11101
# Alaska                         383
# American Samoa                   0
# Arizona                      12674
# Arkansas                      4366
# California                   74871
# Colorado                     20838
# Connecticut                  35464
# Delaware                      7223
# Diamond Princess                49
# District of Columbia          6736
# Florida                      43210
# Georgia                      35977
# Grand Princess                 103
# Guam                           152
# Hawaii                         637
# Idaho                         2351
# Illinois                     87937
# Indiana                      26053
# Iowa                         13675
# Kansas                        7705
# Kentucky                      7225
# Louisiana                    33489
# Maine                         1565
# Maryland                     35903
# Massachusetts                84460
# ...

# %%
jhcounty_grouped_state['6/17/2020'].sum()
# Out:
# Province_State
# Alabama                      27312
# Alaska                         695
# American Samoa                   0
# Arizona                      40937
# Arkansas                     13606
# California                  162798
# Colorado                     29656
# Connecticut                  45429
# Delaware                     10444
# Diamond Princess                49
# District of Columbia          9847
# Florida                      82719
# Georgia                      60030
# Grand Princess                 103
# Guam                           188
# Hawaii                         744
# Idaho                         3632
# Illinois                    134185
# Indiana                      41013
# Iowa                         24460
# Kansas                       11644
# Kentucky                     12995
# Louisiana                    48634
# Maine                         2836
# Maryland                     62969
# Massachusetts               106151
# ...

# %%
jhdeaths_df = pd.read_csv('Deaths by Day by county.csv')
jhdeaths_df
# Out:
#            UID iso2 iso3  code3  FIPS          Admin2  \
# 0           16   AS  ASM     16  60.0             NaN
# 1          316   GU  GUM    316  66.0             NaN
# 2          580   MP  MNP    580  69.0             NaN
# 3          630   PR  PRI    630  72.0             NaN
# 4          850   VI  VIR    850  78.0             NaN
# ...        ...  ...  ...    ...   ...             ...
# 3256  84070016   US  USA    840   NaN    Central Utah
# 3257  84070017   US  USA    840   NaN  Southeast Utah
# 3258  84070018   US  USA    840   NaN  Southwest Utah
# 3259  84070019   US  USA    840   NaN       TriCounty
# 3260  84070020   US  USA    840   NaN    Weber-Morgan
#
#                 Province_State Country_Region        Lat       Long_  ...  \
# 0               American Samoa             US -14.271000 -170.132000  ...
# 1                         Guam             US  13.444300  144.793700  ...
# 2     Northern Mariana Islands             US  15.097900  145.673900  ...
# ...
